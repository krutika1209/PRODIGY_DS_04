# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('twitter.csv')
df
# Out:
#        2401  Borderlands  Positive  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74676  9200       Nvidia  Positive
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
#
#       im getting on borderlands and i will murder you all ,
# 0      I am coming to the borders and I will kill you...
# 1      im getting on borderlands and i will kill you ...
# 2      im coming on borderlands and i will murder you...
# 3      im getting on borderlands 2 and i will murder ...
# 4      im getting into borderlands and i can murder y...
# ...                                                  ...
# 74676  Just realized that the Windows partition of my...
# 74677  Just realized that my Mac window partition is ...
# 74678  Just realized the windows partition of my Mac ...
# 74679  Just realized between the windows partition of...
# 74680  Just like the windows partition of my Mac is l...
#
# [74681 rows x 4 columns]

# %%
df.head(30)
# Out:
#       ID       entity sentiment  \
# 0   2401  Borderlands  Positive
# 1   2401  Borderlands  Positive
# 2   2401  Borderlands  Positive
# 3   2401  Borderlands  Positive
# 4   2401  Borderlands  Positive
# 5   2401  Borderlands  Positive
# 6   2402  Borderlands  Positive
# 7   2402  Borderlands  Positive
# 8   2402  Borderlands  Positive
# 9   2402  Borderlands  Positive
# 10  2402  Borderlands  Positive
# 11  2402  Borderlands  Positive
# 12  2403  Borderlands   Neutral
# 13  2403  Borderlands   Neutral
# 14  2403  Borderlands   Neutral
# 15  2403  Borderlands   Neutral
# 16  2403  Borderlands   Neutral
# 17  2403  Borderlands   Neutral
# 18  2404  Borderlands  Positive
# 19  2404  Borderlands  Positive
# 20  2404  Borderlands  Positive
# 21  2404  Borderlands  Positive
# 22  2404  Borderlands  Positive
# 23  2404  Borderlands  Positive
# 24  2405  Borderlands  Negative
# 25  2405  Borderlands  Negative
# 26  2405  Borderlands  Negative
# 27  2405  Borderlands  Negative
# 28  2405  Borderlands  Negative
# 29  2405  Borderlands  Negative
#
#                                               comment
# 0                           im get borderland murder
# 1                                    come border kill
# 2                              im get borderland kill
# 3                           im come borderland murder
# 4                           im get borderland  murder
# 5                            im get borderland murder
# 6   spent hour make someth fun   dont know huge bo...
# 7   spent coupl hour someth fun dont know im huge ...
# 8   spent hour someth fun dont know im huge  borde...
# 9   spent hour make someth fun   dont know huge rh...
# 10   spent hour make someth fun   dont know huge r...
# 11
# 12  rockhard la varlop rare  power handsom jackpot...
# 13  rockhard la varlop rare  power handsom jackpot...
# 14  rockhard la varlop rare  power handsom jackpot...
# 15  rockhard la vita rare power handsom jackpot bo...
# 16  live rock  hard music la la varlop rare  power...
# 17  ihard like rare london de handsom  borderland ...
# 18  first borderland session long time actual real...
# 19  first borderland session long time actual real...
# 20  first borderland session long time actual real...
# 21  first borderland session long time actual enjo...
# 22  first real borderland session nice long wait t...
# 23  first borderland session hot row actual realli...
# 24  biggest dissappoin life came year ago fuck bor...
# 25              biggest disappoint life came year ago
# 26              biggest disappoint life came year ago
# 27  biggest dissappoin life come year ago fuck bor...
# 28  biggest male dissappoin life came hang year ti...
# 29  biggest dissappoin life came back last year ag...

# %%
col=['ID','entity','sentiment','comment']
df=pd.read_csv('twitter.csv',names=col)
df
# Out:
#          ID       entity sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
# 74681  9200       Nvidia  Positive
#
#                                                  comment
# 0      im getting on borderlands and i will murder yo...
# 1      I am coming to the borders and I will kill you...
# 2      im getting on borderlands and i will kill you ...
# 3      im coming on borderlands and i will murder you...
# 4      im getting on borderlands 2 and i will murder ...
# ...                                                  ...
# 74677  Just realized that the Windows partition of my...
# 74678  Just realized that my Mac window partition is ...
# 74679  Just realized the windows partition of my Mac ...
# 74680  Just realized between the windows partition of...
# 74681  Just like the windows partition of my Mac is l...
#
# [74682 rows x 4 columns]

# %%
df.head(50)
# Out:
#       ID       entity sentiment  \
# 0   2401  Borderlands  Positive
# 1   2401  Borderlands  Positive
# 2   2401  Borderlands  Positive
# 3   2401  Borderlands  Positive
# 4   2401  Borderlands  Positive
# 5   2401  Borderlands  Positive
# 6   2402  Borderlands  Positive
# 7   2402  Borderlands  Positive
# 8   2402  Borderlands  Positive
# 9   2402  Borderlands  Positive
# 10  2402  Borderlands  Positive
# 11  2402  Borderlands  Positive
# 12  2403  Borderlands   Neutral
# 13  2403  Borderlands   Neutral
# 14  2403  Borderlands   Neutral
# 15  2403  Borderlands   Neutral
# 16  2403  Borderlands   Neutral
# 17  2403  Borderlands   Neutral
# 18  2404  Borderlands  Positive
# 19  2404  Borderlands  Positive
# 20  2404  Borderlands  Positive
# 21  2404  Borderlands  Positive
# 22  2404  Borderlands  Positive
# 23  2404  Borderlands  Positive
# 24  2405  Borderlands  Negative
# 25  2405  Borderlands  Negative
# 26  2405  Borderlands  Negative
# 27  2405  Borderlands  Negative
# 28  2405  Borderlands  Negative
# 29  2405  Borderlands  Negative
# 30  2406  Borderlands  Positive
# 31  2406  Borderlands  Positive
# 32  2406  Borderlands  Positive
# 33  2406  Borderlands  Positive
# 34  2406  Borderlands  Positive
# 35  2406  Borderlands  Positive
# 36  2407  Borderlands  Negative
# 37  2407  Borderlands  Negative
# 38  2407  Borderlands  Negative
# 39  2407  Borderlands  Negative
# 40  2407  Borderlands  Negative
# 41  2407  Borderlands  Negative
# 42  2408  Borderlands   Neutral
# 43  2408  Borderlands   Neutral
# 44  2408  Borderlands   Neutral
# 45  2408  Borderlands   Neutral
# 46  2408  Borderlands   Neutral
# 47  2408  Borderlands   Neutral
# 48  2409  Borderlands   Neutral
# 49  2409  Borderlands   Neutral
#
#                                               comment
# 0                           im get borderland murder
# 1                                    come border kill
# 2                              im get borderland kill
# 3                           im come borderland murder
# 4                           im get borderland  murder
# 5                            im get borderland murder
# 6   spent hour make someth fun   dont know huge bo...
# 7   spent coupl hour someth fun dont know im huge ...
# 8   spent hour someth fun dont know im huge  borde...
# 9   spent hour make someth fun   dont know huge rh...
# 10   spent hour make someth fun   dont know huge r...
# 11
# 12  rockhard la varlop rare  power handsom jackpot...
# 13  rockhard la varlop rare  power handsom jackpot...
# 14  rockhard la varlop rare  power handsom jackpot...
# 15  rockhard la vita rare power handsom jackpot bo...
# 16  live rock  hard music la la varlop rare  power...
# 17  ihard like rare london de handsom  borderland ...
# 18  first borderland session long time actual real...
# 19  first borderland session long time actual real...
# 20  first borderland session long time actual real...
# 21  first borderland session long time actual enjo...
# 22  first real borderland session nice long wait t...
# 23  first borderland session hot row actual realli...
# 24  biggest dissappoin life came year ago fuck bor...
# 25              biggest disappoint life came year ago
# 26              biggest disappoint life came year ago
# 27  biggest dissappoin life come year ago fuck bor...
# 28  biggest male dissappoin life came hang year ti...
# 29  biggest dissappoin life came back last year ag...
# 30  finish borderland  final yas thank hang everyo...
# 31  final final find borderland  yes thank hang fu...
# 32  thank hang everyon fun ill tri get haircut tom...
# 33  finish borderland  updat yas thank hang guy fu...
# 34  finish borderland  final yas thank everyon han...
# 35  finish borderland  final yas hey hang fun tri ...
# 36  man gearbox realli need fix dissapoint drop ne...
# 37  man gearbox realli need fix disappoint drop ne...
# 38  man gearbox realli need fix disssapoint drop n...
# 39  man bethesda realli need fix dissapoint drop n...
# 40  man gearbox realli need fix dissapoint drop co...
# 41   gearbox realli time fix  drop new borderland ...
# 42                              check epic streamer
# 43                                check epic streamer
# 44                               watch epic stripteas
# 45                                check epic streamer
# 46                            check big epic streamer
# 47                                check epic streamer
# 48  blame sight tardi littl bit borderland got cal...
# 49  bit borderland call work tomorrow morn cant ca...

# %%
df.tail(50)
# Out:
#          ID  entity sentiment  \
# 74632  9192  Nvidia   Neutral
# 74633  9192  Nvidia   Neutral
# 74634  9193  Nvidia  Positive
# 74635  9193  Nvidia  Positive
# 74636  9193  Nvidia  Positive
# 74637  9193  Nvidia  Positive
# 74638  9193  Nvidia  Positive
# 74639  9193  Nvidia  Positive
# 74640  9194  Nvidia  Positive
# 74641  9194  Nvidia  Positive
# 74642  9194  Nvidia  Positive
# 74643  9194  Nvidia  Positive
# 74644  9194  Nvidia  Positive
# 74645  9194  Nvidia  Positive
# 74646  9195  Nvidia   Neutral
# 74647  9195  Nvidia   Neutral
# 74648  9195  Nvidia   Neutral
# 74649  9195  Nvidia   Neutral
# 74650  9195  Nvidia   Neutral
# 74651  9195  Nvidia   Neutral
# 74652  9196  Nvidia  Negative
# 74653  9196  Nvidia  Negative
# 74654  9196  Nvidia  Negative
# 74655  9196  Nvidia  Negative
# 74656  9196  Nvidia  Negative
# 74657  9196  Nvidia  Negative
# 74658  9197  Nvidia   Neutral
# 74659  9197  Nvidia   Neutral
# 74660  9197  Nvidia   Neutral
# 74661  9197  Nvidia   Neutral
# 74662  9197  Nvidia   Neutral
# 74663  9197  Nvidia   Neutral
# 74664  9198  Nvidia  Negative
# 74665  9198  Nvidia  Negative
# 74666  9198  Nvidia  Negative
# 74667  9198  Nvidia  Negative
# 74668  9198  Nvidia  Negative
# 74669  9198  Nvidia  Negative
# 74670  9199  Nvidia  Positive
# 74671  9199  Nvidia  Positive
# 74672  9199  Nvidia  Positive
# 74673  9199  Nvidia  Positive
# 74674  9199  Nvidia  Positive
# 74675  9199  Nvidia  Positive
# 74676  9200  Nvidia  Positive
# 74677  9200  Nvidia  Positive
# 74678  9200  Nvidia  Positive
# 74679  9200  Nvidia  Positive
# 74680  9200  Nvidia  Positive
# 74681  9200  Nvidia  Positive
#
#                                                  comment
# 74632  save   aero  ole  edg award  win desk design s...
# 74633   aero va ole  award win design stun  ole panel...
# 74634                                     love everyth
# 74635                                       love everyth
# 74636                                       love everyth
# 74637                                     love everyth �
# 74638                                       love everyth
# 74639                                 love everyth anyth
# 74640  check new gpu driver today went amd driver sec...
# 74641  today search new gpu driver went amd driver se...
# 74642                rememb switch amd nvidia  month ago
# 74643  check new gpu driver today type amd driver sec...
# 74644  check new gpu power driver today went amd driv...
# 74645  check new gpu driver today click amd driver se...
# 74646  nvidia releas secur updat driver fix sever iss...
# 74647  nvidia releas secur updat driver fix sever iss...
# 74648  nvidia releas secur updat driver fix sever pro...
# 74649  nvidia releas anoth softwar updat driver fix s...
# 74650  nvidia releas new secur updat driver fix sever...
# 74651  nvidia releas substanti updat driver identifi ...
# 74652  cheap doesnt mean better btw   techsallcomgoog...
# 74653   cheap mean better way techsallcom  googlechallen
# 74654
# 74655        cheap mean better techsallcomgooglechallen…
# 74656   cheap doesnt mean anyon better btw techsal co...
# 74657     realli doesnt look bad btw netcomgooglechallen
# 74658  nvidia doesn't want give  crypto craze' doc ma...
# 74659  nvidia plan releas  crypto craze documentari m...
# 74660  nvidia want give cryptoinsan doxmaxbitcc  nvid...
# 74661  nvidia doesn't intend give away  ad craze' doc...
# 74662  nvidia therefor ’ want give  ‘ crypto craze ’ ...
# 74663  doesn't give password crypto wallet doc maxbit...
# 74664                       nvidia realli delay   week
# 74665                         nvidia realli delay   week
# 74666                                nvidia delay   week
# 74667                    nvidia realli delay  sever week
# 74668                  nvidia realli delay   flight week
# 74669                     nvidia realli delay next  week
# 74670  let elim go unnot    nvidia highlight automat ...
# 74671  let elim go unnot nvidia highlight automat rec...
# 74672  let elit go unnot nvidia highlight automat rec...
# 74673  let elim go unnot nvidia highlight automat rec...
# 74674  let inform elim go unnot nvidia highlight auto...
# 74675   elim nvidia highlight pictur reveal best mome...
# 74676  realiz window partit mac like  year behind nvi...
# 74677  realiz window partit mac like  year behind nvi...
# 74678  realiz mac window partit  year behind nvidia d...
# 74679  realiz window partit mac  year behind nvidia d...
# 74680  realiz window partit mac like  year behind nvi...
# 74681  like window partit mac like  year behind drive...

# %%
df.describe()
# Out:
#                  ID
# count  74682.000000
# mean    6432.586165
# std     3740.427870
# min        1.000000
# 25%     3195.000000
# 50%     6422.000000
# 75%     9601.000000
# max    13200.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74682 entries, 0 to 74681
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         74682 non-null  int64
#  1   entity     74682 non-null  object
#  2   sentiment  74682 non-null  object
#  3   comment    73996 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 2.3+ MB

# %%
df.dtypes
# Out:
# ID            int64
# entity       object
# sentiment    object
# comment      object
# dtype: object

# %%
df.duplicated().sum()
# Out:
# 2700

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# ID             0
# entity         0
# sentiment      0
# comment      326
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# ID           0
# entity       0
# sentiment    0
# comment      0
# dtype: int64

# %%
df.nunique().sum()
# Out:
# 81974

# %%
df['sentiment'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        Positive
# 1        Positive
# 2        Positive
# 3        Positive
# 4        Positive
#            ...
# 74677    Positive
# 74678    Positive
# 74679    Positive
# 74680    Positive
# 74681    Positive
# Name: sentiment, Length: 71656, dtype: object>

# %%
sns.countplot(x='sentiment', data=df)
plt.title('Sentiment Distribution')
plt.show()

# %%
#Count information per category
plot1=df.groupby(by=["sentiment","entity"]).count().reset_index()
plot1.head()
# Out:
#     sentiment          entity   ID  comment
# 0  Irrelevant          Amazon  185      185
# 1  Irrelevant     ApexLegends  185      185
# 2  Irrelevant  AssassinsCreed  256      256
# 3  Irrelevant     Battlefield  907      907
# 4  Irrelevant     Borderlands  238      238

# %%
#Figure of comparison per branch
plt.figure(figsize=(20,6))
sns.barplot(data=plot1,x="entity",y="ID",hue="sentiment")
plt.xticks(rotation=90)
plt.xlabel("Brand")
plt.ylabel("Number of tweets")
plt.grid()
plt.title("Distribution of tweets per Entity and sentiment");

# %%
plt.figure(figsize=(15,9))
sns.barplot(x=df['entity'].value_counts().values,y=df['entity'].value_counts().index)
plt.xlabel('Type')
plt.ylabel('Count')
plt.title('Entity Distribution')
plt.show()

# %%
average_sentiment_by_entity = df.groupby('entity')['sentiment'].value_counts(normalize=True).unstack()
average_sentiment_by_entity.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Average Sentiment by Entity')
plt.xticks(rotation=45, fontsize=6)
plt.show()

# %%
pip install textblob
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: textblob in c:\users\korde\appdata\roaming\python\python39\site-packages (0.18.0.post0)
# Requirement already satisfied: nltk>=3.8 in c:\users\korde\appdata\roaming\python\python39\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (2022.7.9)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (8.0.4)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (4.64.1)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (1.1.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click->nltk>=3.8->textblob) (0.4.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from textblob import TextBlob

# %%
from textblob import TextBlob
import pandas as pd

# Sample DataFrame
data = {'comment': ['I love this product!', 'This is the worst service ever.', 'Not bad, could be better.']}
df = pd.DataFrame(data)

# Define the analyze_sentiment function
def analyze_sentiment(text):
    analysis = TextBlob(text)
    return analysis.sentiment.polarity

# Perform sentiment analysis
df['Polarity'] = df['comment'].apply(analyze_sentiment)
df.head(5)
# Out:
#                            comment  Polarity
# 0             I love this product!     0.625
# 1  This is the worst service ever.    -1.000
# 2        Not bad, could be better.     0.425

# %%
df['Polarity'].value_counts()
# Out:
#  0.625    1
# -1.000    1
#  0.425    1
# Name: Polarity, dtype: int64

# %%
df.dtypes
# Out:
# comment      object
# Polarity    float64
# dtype: object

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Polarity'], bins=20, edgecolor='k')
plt.title('Polarity Score Distribution')
plt.xlabel('Polarity Score')
plt.ylabel('Count')
plt.show()

# %%
# Visualize the most positive and negative tweets
most_positive_tweet = df[df['Polarity'] == df['Polarity'].max()]['comment'].values[0]
most_negative_tweet = df[df['Polarity'] == df['Polarity'].min()]['comment'].values[0]

print('Most Positive Tweet:')
print(most_positive_tweet)

print('\nMost Negative Tweet:')
print(most_negative_tweet)
# Out:
# Most Positive Tweet:
# I love this product!
#
# Most Negative Tweet:
# This is the worst service ever.

# %%
import nltk
import re
stemmer = nltk.SnowballStemmer("english")
nltk.download('stopwords')
from nltk.corpus import stopwords
import string
stopword=set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\korde\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def clean(text):
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = [word for word in text.split(' ') if word not in stopword]
    text=" ".join(text)
    text = [stemmer.stem(word) for word in text.split(' ')]
    text=" ".join(text)
    return text

# %%
df["comment"] = df["comment"].apply(clean)

# %%
df.head()
# Out:
#      ID       entity sentiment                    comment
# 0  2401  Borderlands  Positive  im get borderland murder
# 1  2401  Borderlands  Positive           come border kill
# 2  2401  Borderlands  Positive     im get borderland kill
# 3  2401  Borderlands  Positive  im come borderland murder
# 4  2401  Borderlands  Positive  im get borderland  murder

# %%
pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting wordcloud
#   Downloading wordcloud-1.9.3-cp39-cp39-win_amd64.whl (300 kB)
#      ------------------------------------ 300.6/300.6 kB 476.8 kB/s eta 0:00:00
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (9.2.0)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (3.5.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script wordcloud_cli.exe is installed in 'C:\Users\korde\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
from wordcloud import WordCloud,STOPWORDS
wc = WordCloud(width=800,height=500,min_font_size=10,background_color='white')

# %%
#Word Cloud : Positive sentiment
from PIL import Image, ImageDraw, ImageFont

# %%
positive_data = df[df['sentiment'] == 'Positive']['comment'].str.cat(sep=" ")

# %%
# Exclude the word "game" from the text data
positive_data = positive_data.replace("game", "")
if positive_data:
    wc = WordCloud(width=800, height=500, background_color='white').generate(positive_data)
    plt.figure(figsize=(12, 6))
    plt.title('Positive Sentiment Word Cloud')
    plt.imshow(wc)
    plt.axis("off")
    plt.show()
else:
    print("No data available for positive sentiment.")

# %%
#Word Cloud : Negative Sentiment
negative_data = df[df['sentiment'] == 'Negative']['comment'].str.cat(sep=" ")

# %%
# Exclude the word "game" from the text data
negative_data = negative_data.replace("game", "")
if negative_data.strip():
    wc = WordCloud(width=800, height=500, background_color='white').generate(negative_data)
    plt.figure(figsize=(12, 6))
    plt.title('Negative Sentiment Word Cloud')
    plt.imshow(wc)
    plt.axis("off")
    plt.show()
else:
    print("No data available for negative sentiment.")

# %%
#Word Cloud : Irrelevant Sentiment
irrelevant_data = df[df['sentiment'] == 'Irrelevant']['comment'].str.cat(sep=" ")

# %%
irrelevant_data = irrelevant_data.replace("game", "")

if irrelevant_data.strip():
    wc = WordCloud(width=800, height=400, background_color='white').generate(irrelevant_data)
    plt.figure(figsize=(12, 6))
    plt.title('Irrelevant Sentiment Word Cloud')
    plt.imshow(wc)
    plt.axis("off")
    plt.show()
else:
    print("No data available for irrelevant sentiment.")
